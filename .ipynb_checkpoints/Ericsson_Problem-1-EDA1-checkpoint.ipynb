# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('train_file.csv')

# %%
train_df
# Out:
#           ID      Place                      location           date  \
# 0          1  startup_1                           NaN   Dec 11, 2018
# 1          5  startup_1               Los Angeles, CA   Jul 19, 2018
# 2          9  startup_1                  New York, NY   Dec 10, 2018
# 3         16  startup_1                           NaN    Dec 6, 2018
# 4         17  startup_1                           NaN   Nov 29, 2018
# 5         18  startup_1                           NaN    Dec 2, 2018
# 6         19  startup_1                           NaN    Dec 1, 2018
# 7         21  startup_1                  New York, NY   Nov 26, 2018
# 8         22  startup_1                           NaN    Dec 2, 2018
# 9         23  startup_1                           NaN    Dec 1, 2018
# 10        24  startup_1                           NaN   Nov 30, 2018
# 11        25  startup_1               Los Angeles, CA   Nov 29, 2018
# 12        26  startup_1                           NaN   Nov 29, 2018
# ...

# %%
train_df.groupby('')
# Out:
# array([  0,  49,   2,   1,   4,  12,   6,   7,   3,   9,  14,   8,   5,
#         10,  24,  13,  26,  11,  25,  29,  19,  15,  23,  16,  22,  17,
#         50,  21,  42,  46,  18, 257, 245,  32, 193,  20,  37,  57,  34,
#         30,  27,  64, 117,  43,  41,  28,  31,  51,  89,  36,  62, 121,
#         88,  33, 214,  44,  52,  55, 449,  38,  35,  40,  58, 136, 100,
#        110])
