# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math

# %%
train_df = pd.read_csv('Predictive_Data/train_file.csv')

# %%
train_df
# Out:
#           ID                                              Title  \
# 0          1                                         Tidal wave
# 1          2                     London holiday / Richard Peck.
# 2          3  Cinco de Mayo : celebrating Hispanic pride / C...
# 3          4                                          Annapolis
# 4          5                                  As a man thinketh
# 5          6  Minnie and Moo go dancing / [written and illus...
# 6          7                              cat who robbed a bank
# 7          8       Irwin guide to using the Wall Street journal
# 8          9                                       Oracle night
# 9         10                                12 haunted episodes
# 10        11  The Roman army, 31 BC-AD 337 : a sourcebook / ...
# 11        12                   The Ink Spots [sound recording].
# 12        13  First 24 hours of war in the Pacific / by Dona...
# 13        14                                Where do birds live
# ...

# %%
dictionary = {}

for it in train_df.groupby('MaterialType').__iter__():
    x,y = it
    dictionary[x] = [y[column].unique() for column in y.column.values]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-1ea79f9efb88> in <module>()
#       3 for it in train_df.groupby('MaterialType').__iter__():
#       4     x,y = it
# ----> 5     dictionary[x] = [y[column].unique() for column in y.column.values]
#
# ~/anaconda3/envs/hackathon/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'
