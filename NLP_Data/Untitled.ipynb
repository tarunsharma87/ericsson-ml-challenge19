# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('train.csv')
del df['ID']
del df['score_6']

# %%
df.head()
# Out:
#        Place           location           date             status  \
# 0  startup_1                NaN   Dec 11, 2018  Current Employee
# 1  startup_1  Mountain View, CA   Jun 21, 2013   Former Employee
# 2  startup_1       New York, NY   May 10, 2014  Current Employee
# 3  startup_1  Mountain View, CA    Feb 8, 2015  Current Employee
# 4  startup_1                NaN    Dec 9, 2018  Current Employee
#
#                 job_title                                            summary  \
# 0      Anonymous Employee                           Best Company to work for
# 1         Program Manager  Moving at the speed of light, burn out is inev...
# 2   Software Engineer III  Great balance between big-company security and...
# 3      Anonymous Employee  The best place I've worked and also the most d...
# 4      Anonymous Employee                           Execellent for engineers
#
#                                            positives  \
# 0                      People are smart and friendly
# ...

# %%
df.shape
# Out:
# (30336, 15)

# %%
df.isna().sum()
# Out:
# Place                 0
# location          11254
# date                  0
# status                0
# job_title             0
# summary              52
# positives             0
# negatives             0
# advice_to_mgmt    13277
# score_1            3186
# score_2            6050
# score_3            3169
# score_4            3191
# score_5            3485
# overall               0
# dtype: int64

# %% [markdown]
# # Descriptive Stats

# %%
df.describe()
# Out:
#             score_1       score_2       score_3       score_4       score_5  \
# count  27150.000000  24286.000000  27167.000000  27145.000000  26851.000000
# mean       3.370460      3.784773      3.630047      3.943986      3.322446
# std        1.301983      1.300164      1.225714      1.043053      1.314696
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      3.000000      3.000000      3.000000      2.000000
# 50%        3.500000      4.000000      4.000000      4.000000      3.000000
# 75%        4.000000      5.000000      5.000000      5.000000      4.000000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#             overall
# count  30336.000000
# mean       3.588179
# std        0.996981
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000

# %%
df.corr()
# Out:
#           score_1   score_2   score_3   score_4   score_5   overall
# score_1  1.000000  0.574424  0.465877  0.421480  0.573240  0.457094
# score_2  0.574424  1.000000  0.587096  0.468280  0.717165  0.420812
# score_3  0.465877  0.587096  1.000000  0.514425  0.632402  0.466800
# score_4  0.421480  0.468280  0.514425  1.000000  0.470269  0.399936
# score_5  0.573240  0.717165  0.632402  0.470269  1.000000  0.462248
# overall  0.457094  0.420812  0.466800  0.399936  0.462248  1.000000

# %% [markdown]
# ## Univariate data plotting

# %%
df.hist(figsize=(20,15))
plt.show()

# %%
df.plot(kind='density', subplots=True, layout=(3,3), figsize=(15,10))
plt.show()

# %%
df.boxplot(figsize=(10,5))
plt.show()

# %% [markdown]
# ## Multivariate data plotting

# %%
plt.matshow(df.corr())

# %%
pd.scatter_matrix(df, figsize=(20,15))
plt.show()
# Out:
# /home/info/anaconda3/envs/hackathon/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
